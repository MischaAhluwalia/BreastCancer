# %%
# Import liberaries (collections of precompiled codes)
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
# lv_filename is variable for the filename
# df_data is variable for the table
lv_filename = "D:\\10 Klasse\\SourceCode\\BreastCancer\\Breast_cancer_data.csv"
df_data = pd.read_csv(lv_filename,sep=";",decimal=",")

# %%
# Plots Histogram
# Figsize = Sccale
fig, axs = plt.subplots(1, 1,
                        figsize =(5, 5),
                        tight_layout = True)
 
n=100
axs.hist(df_data["mean_radius"].sort_values(),bins = 50)
plt.show()

# %%
# Plots line graph!
# Step 1: Sort all values from small to large by the mean radius
df_data = df_data.sort_values(by = ["mean_radius"])
plt.plot(df_data["mean_radius"], df_data["mean_area"])
